# %%
# 🚀 train_ultimate_mobilenetv2.py

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import cv2
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

def get_gradcam_heatmap(model, image_array, class_index, last_conv_layer_name='Conv_1'):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(image_array)
        loss = predictions[:, class_index]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# -------------------- Parameters --------------------
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS_PHASE1 = 20
EPOCHS_PHASE2 = 15
INIT_LR = 0.001

# -------------------- Directory Setup --------------------
TRAIN_DIR = r'C:\Users\MANJU\Desktop\FYP_MoreData\split_data\train'
VAL_DIR = r'C:\Users\MANJU\Desktop\FYP_MoreData\split_data\val'
TEST_DIR = r'C:\Users\MANJU\Desktop\FYP_MoreData\split_data\test'

# -------------------- Data Augmentation --------------------
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_gen = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_gen = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# -------------------- Build Model --------------------
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer=Adam(learning_rate=INIT_LR),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# -------------------- Callbacks --------------------
checkpoint = ModelCheckpoint('models/mobilenetv2_best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-6, verbose=1)

# -------------------- Phase 1: Transfer Learning --------------------
history1 = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_PHASE1,
                     callbacks=[checkpoint, earlystop, reduce_lr])

# -------------------- Phase 2: Fine Tuning --------------------
for layer in base_model.layers[-60:]:
    layer.trainable = True

model.compile(optimizer=Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

history2 = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_PHASE2,
                     callbacks=[checkpoint, earlystop, reduce_lr])

# -------------------- Plot Training Curves --------------------
acc = history1.history['accuracy'] + history2.history['accuracy']
val_acc = history1.history['val_accuracy'] + history2.history['val_accuracy']
loss = history1.history['loss'] + history2.history['loss']
val_loss = history1.history['val_loss'] + history2.history['val_loss']

plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
plt.plot(acc, label='Train Accuracy')
plt.plot(val_acc, label='Val Accuracy')
plt.title("Accuracy Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.title("Loss Curve")
plt.legend()
plt.tight_layout()
plt.savefig("training_curves.png")
plt.show()

# -------------------- Evaluation --------------------
loss, acc = model.evaluate(test_gen)
print(f"\n🔥 Final Test Accuracy: {acc*100:.2f}%")

y_pred = model.predict(test_gen)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_gen.classes

print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=['Non-Diabetic', 'Diabetic']))

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', xticklabels=['Non-Diabetic', 'Diabetic'], yticklabels=['Non-Diabetic', 'Diabetic'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.savefig("confusion_matrix.png")
plt.show()

# Grad-CAM for a sample test image
sample_img_path = test_gen.filepaths[5]  # Change index as desired
sample_img = tf.keras.utils.load_img(sample_img_path, target_size=IMG_SIZE)
sample_array = tf.keras.utils.img_to_array(sample_img) / 255.0
sample_array_exp = np.expand_dims(sample_array, axis=0)

preds = model.predict(sample_array_exp)
pred_class = np.argmax(preds[0])
class_labels = list(test_gen.class_indices.keys())

heatmap = get_gradcam_heatmap(model, sample_array_exp, class_index=pred_class)

# Superimpose heatmap
heatmap_resized = cv2.resize(heatmap, IMG_SIZE)
heatmap_colored = cv2.applyColorMap(np.uint8(255 * heatmap_resized), cv2.COLORMAP_JET)
superimposed_img = heatmap_colored * 0.4 + np.uint8(sample_array * 255)

# Show Grad-CAM Results
plt.figure(figsize=(10,4))
plt.subplot(1,3,1)
plt.imshow(sample_img)
plt.title("Original Image")

plt.subplot(1,3,2)
plt.imshow(heatmap_resized, cmap='jet')
plt.title("Grad-CAM Heatmap")

plt.subplot(1,3,3)
plt.imshow(np.uint8(superimposed_img))
plt.title(f"Predicted: {class_labels[pred_class]}")

plt.tight_layout()
plt.savefig("gradcam_sample.png")
plt.show()

for layer in model.layers[::-1]:
    if 'conv' in layer.name.lower():
        print("Last conv layer:", layer.name)
        break
# Out:
# Found 226 images belonging to 2 classes.
# Found 48 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 973ms/step - accuracy: 0.5867 - loss: 1.0421
# Epoch 1: val_accuracy improved from -inf to 0.72917, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5928 - loss: 1.0342 - val_accuracy: 0.7292 - val_loss: 0.4443 - learning_rate: 0.0010
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7412 - loss: 0.6551
# Epoch 2: val_accuracy did not improve from 0.72917
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7434 - loss: 0.6531 - val_accuracy: 0.7292 - val_loss: 0.4572 - learning_rate: 0.0010
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7814 - loss: 0.5738
# Epoch 3: val_accuracy improved from 0.72917 to 0.77083, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7821 - loss: 0.5692 - val_accuracy: 0.7708 - val_loss: 0.5491 - learning_rate: 0.0010
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8296 - loss: 0.3783
# Epoch 4: val_accuracy did not improve from 0.77083
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8288 - loss: 0.3873 - val_accuracy: 0.7708 - val_loss: 0.5062 - learning_rate: 0.0010
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8587 - loss: 0.3437
# Epoch 5: val_accuracy did not improve from 0.77083
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8533 - loss: 0.3484 - val_accuracy: 0.7708 - val_loss: 0.4461 - learning_rate: 3.0000e-04
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - accuracy: 0.8946 - loss: 0.3043
# Epoch 6: val_accuracy improved from 0.77083 to 0.79167, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8935 - loss: 0.3102 - val_accuracy: 0.7917 - val_loss: 0.3969 - learning_rate: 3.0000e-04
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7611 - loss: 0.4623
# Epoch 7: val_accuracy did not improve from 0.79167
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7694 - loss: 0.4501 - val_accuracy: 0.7917 - val_loss: 0.3735 - learning_rate: 3.0000e-04
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8633 - loss: 0.3088
# Epoch 8: val_accuracy did not improve from 0.79167
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8638 - loss: 0.3064 - val_accuracy: 0.7708 - val_loss: 0.3429 - learning_rate: 3.0000e-04
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 993ms/step - accuracy: 0.8648 - loss: 0.3501
# Epoch 9: val_accuracy did not improve from 0.79167
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8676 - loss: 0.3450 - val_accuracy: 0.7708 - val_loss: 0.3264 - learning_rate: 3.0000e-04
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8841 - loss: 0.3124
# Epoch 10: val_accuracy did not improve from 0.79167
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8837 - loss: 0.3130 - val_accuracy: 0.7917 - val_loss: 0.3214 - learning_rate: 3.0000e-04
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8809 - loss: 0.2916
# Epoch 11: val_accuracy improved from 0.79167 to 0.81250, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8828 - loss: 0.2891 - val_accuracy: 0.8125 - val_loss: 0.3215 - learning_rate: 3.0000e-04
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 897ms/step - accuracy: 0.9021 - loss: 0.2691
# Epoch 12: val_accuracy did not improve from 0.81250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9002 - loss: 0.2740 - val_accuracy: 0.8125 - val_loss: 0.3227 - learning_rate: 3.0000e-04
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8305 - loss: 0.3241
# Epoch 13: val_accuracy did not improve from 0.81250
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8356 - loss: 0.3181 - val_accuracy: 0.7917 - val_loss: 0.3236 - learning_rate: 3.0000e-04
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9228 - loss: 0.2398
# Epoch 14: val_accuracy improved from 0.81250 to 0.83333, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9206 - loss: 0.2465 - val_accuracy: 0.8333 - val_loss: 0.3201 - learning_rate: 9.0000e-05
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8842 - loss: 0.2700
# Epoch 15: val_accuracy did not improve from 0.83333
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8843 - loss: 0.2705 - val_accuracy: 0.8333 - val_loss: 0.3177 - learning_rate: 9.0000e-05
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9179 - loss: 0.2125
# Epoch 16: val_accuracy improved from 0.83333 to 0.87500, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9162 - loss: 0.2177 - val_accuracy: 0.8750 - val_loss: 0.3190 - learning_rate: 9.0000e-05
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8945 - loss: 0.2509
# Epoch 17: val_accuracy did not improve from 0.87500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8949 - loss: 0.2501 - val_accuracy: 0.8750 - val_loss: 0.3229 - learning_rate: 9.0000e-05
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9003 - loss: 0.2801
# Epoch 18: val_accuracy improved from 0.87500 to 0.89583, saving model to models/mobilenetv2_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9021 - loss: 0.2771 - val_accuracy: 0.8958 - val_loss: 0.3284 - learning_rate: 9.0000e-05
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.8698 - loss: 0.2888
# Epoch 19: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8715 - loss: 0.2851 - val_accuracy: 0.8958 - val_loss: 0.3316 - learning_rate: 2.7000e-05
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - accuracy: 0.9359 - loss: 0.1721
# Epoch 20: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9347 - loss: 0.1749 - val_accuracy: 0.8958 - val_loss: 0.3319 - learning_rate: 2.7000e-05
# Epoch 1/15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7217 - loss: 0.6248
# Epoch 1: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.7221 - loss: 0.6275 - val_accuracy: 0.8125 - val_loss: 0.3152 - learning_rate: 1.0000e-05
# Epoch 2/15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7019 - loss: 0.7069
# Epoch 2: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7006 - loss: 0.7105 - val_accuracy: 0.7917 - val_loss: 0.3226 - learning_rate: 1.0000e-05
# Epoch 3/15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8339 - loss: 0.5022
# Epoch 3: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8283 - loss: 0.5136 - val_accuracy: 0.7917 - val_loss: 0.3425 - learning_rate: 1.0000e-05
# Epoch 4/15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7745 - loss: 0.5074
# Epoch 4: val_accuracy did not improve from 0.89583
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7740 - loss: 0.5094 - val_accuracy: 0.7917 - val_loss: 0.3696 - learning_rate: 1.0000e-05
# Epoch 5/15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7314 - loss: 0.6572
# Epoch 5: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7328 - loss: 0.6561 - val_accuracy: 0.7708 - val_loss: 0.4020 - learning_rate: 3.0000e-06
# Epoch 6/15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7251 - loss: 0.6271
# Epoch 6: val_accuracy did not improve from 0.89583
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7276 - loss: 0.6228 - val_accuracy: 0.7917 - val_loss: 0.4421 - learning_rate: 3.0000e-06
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - accuracy: 0.9733 - loss: 0.1701
#
# 🔥 Final Test Accuracy: 96.00%
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002D934911DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002D934911DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 2s 3s/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002D934911DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002D934911DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Non-Diabetic       0.97      0.97      0.97        38
#     Diabetic       0.92      0.92      0.92        12
#
#     accuracy                           0.96        50
#    macro avg       0.95      0.95      0.95        50
# weighted avg       0.96      0.96      0.96        50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# C:\Users\MANJU\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['keras_tensor_644']]
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
# Last conv layer: Conv_1_bn
